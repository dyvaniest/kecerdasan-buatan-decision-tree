# %% [markdown]
# # Kelompok PSTI D
#
# # 1. Divany Pangestika       (2215061036)
# # 2. Safitri Mutiara Putri   (2215061028)
# # 3. Amelia Putri            (2215061088)
# # 4. Evana Eka Wijaya        (2215061128)

# %% [markdown]
# # Decision Tree Classification

# %%
import pandas as pd

# %%
df = pd.read_csv("university.csv")
df.head()
# Out:
#             university                   major     degree  cumlaude
# 0  universitas lampung  electrical engineering  bachelors         1
# 1  universitas lampung  electrical engineering    masters         1
# 2  universitas lampung  mechanical engineering  bachelors         0
# 3  universitas lampung  mechanical engineering    masters         0
# 4  universitas lampung        computer science  bachelors         1

# %%
inputs = df.drop('cumlaude', axis='columns')

# %%
target = df['cumlaude']

# %%
from sklearn.preprocessing import LabelEncoder
le_university = LabelEncoder()
le_major = LabelEncoder()
le_degree = LabelEncoder()

# %%
inputs['university_n'] = le_university.fit_transform(inputs['university'])
inputs['major_n'] = le_major.fit_transform(inputs['major'])
inputs['degree_n'] = le_degree.fit_transform(inputs['degree'])

# %%
inputs
# Out:
#                university                   major     degree  university_n  \
# 0     universitas lampung  electrical engineering  bachelors             1
# 1     universitas lampung  electrical engineering    masters             1
# 2     universitas lampung  mechanical engineering  bachelors             1
# 3     universitas lampung  mechanical engineering    masters             1
# 4     universitas lampung        computer science  bachelors             1
# 5     universitas lampung        computer science    masters             1
# 6   universitas teknokrat  electrical engineering    masters             2
# 7   universitas teknokrat        computer science  bachelors             2
# 8   universitas teknokrat  mechanical engineering  bachelors             2
# 9   universitas teknokrat  mechanical engineering    masters             2
# 10                  itera  electrical engineering  bachelors             0
# ...

# %%
inputs_n = inputs.drop(['university','major','degree'],axis='columns')

# %%
inputs_n
# Out:
#     university_n  major_n  degree_n
# 0              1        1         0
# 1              1        1         1
# 2              1        2         0
# 3              1        2         1
# 4              1        0         0
# 5              1        0         1
# 6              2        1         1
# 7              2        0         0
# 8              2        2         0
# 9              2        2         1
# 10             0        1         0
# 11             0        1         1
# 12             0        2         0
# 13             0        2         1
# 14             0        0         0
# 15             0        0         1

# %%
target
# Out:
# 0     1
# 1     1
# 2     0
# 3     0
# 4     1
# 5     0
# 6     1
# 7     1
# 8     1
# 9     0
# 10    0
# 11    0
# 12    0
# 13    0
# 14    0
# 15    0
# Name: cumlaude, dtype: int64
